# %%
# %autoreload 2

# %%
# %reload_ext autoreload

import numpy as np
import nrrd, tifffile
import sys
sys.path.append(r'C://Users//Zichen//anaconda3//envs//2ptank//Lib//site-packages//')
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 13})

# %% [markdown]
# __LOAD MAPZBRAIN ATLAS__

# %%
data, header = nrrd.read("C:\Data\MapZBrainATLAS\standard_brain_fixed_SYP_T_GAD1b.nrrd")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Zichen\AppData\Local\Temp\ipykernel_6336\4036682512.py:1: SyntaxWarning: invalid escape sequence '\D'
#   data, header = nrrd.read("C:\Data\MapZBrainATLAS\standard_brain_fixed_SYP_T_GAD1b.nrrd")

# %%
plt.imshow(data[:, :, 228])
plt.show()
plt.close()

# %%
data2 = tifffile.imread("C:\Data\MapZBrainATLAS\T_AVG_HuCD.tif")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Zichen\AppData\Local\Temp\ipykernel_6336\1436708251.py:1: SyntaxWarning: invalid escape sequence '\D'
#   data2 = tifffile.imread("C:\Data\MapZBrainATLAS\T_AVG_HuCD.tif")

# %%
plt.imshow(data2[128, :, :], vmax = 30)
plt.show()
plt.close()

# %% [markdown]
# LOAD REGIONS

# %%
region = tifffile.imread("C:\Data\MapZBrainATLAS\mapZebrain__regions__v1.0//abducens_motor_nucleus.tif")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Zichen\AppData\Local\Temp\ipykernel_6336\1112815594.py:1: SyntaxWarning: invalid escape sequence '\D'
#   region = tifffile.imread("C:\Data\MapZBrainATLAS\mapZebrain__regions__v1.0//abducens_motor_nucleus.tif")

# %%
plt.imshow(region.max(axis = 0), vmax = 30)
plt.show()
plt.close()
